# %%
import pandas as pd

# %%
customers= pd.read_csv(r"C:\Users\Hasini\Downloads\day_1\src\cleaned_customer_contacts_2Q.csv")

# %%
transactions = pd.read_csv(r"C:\Users\Hasini\Downloads\day_1\transaction_data.csv")

# %%
merged_data = pd.merge(customers, transactions, on='customer_id', how='inner')

# %%
print(merged_data)
# Out:
#      customer_id              name                        email  \
# 0              1     Michelle Kidd           vayala@example.net
# 1              4    Kimberly Price    jessicaknight@example.com
# 2              5  Matthew Phillips        qwilliams@example.com
# 3              7      Louis Miller  patriciaelliott@example.org
# 4              7      Louis Miller  patriciaelliott@example.org
# ..           ...               ...                          ...
# 995          995    Deanna Johnson            ycook@example.org
# 996          995    Deanna Johnson            ycook@example.org
# 997          997      Jodi Simpson           eric24@example.org
# 998          998     Crystal Brown         pshaffer@example.net
# 999          998     Crystal Brown         pshaffer@example.net
#
#                phone                                            address  \
# 0    +1-619-723-4258                        USNS Santiago, FPO AE 80872
# ...

# %%
print(merged_data.to_string())
# Out:
#      customer_id                        name                                email            phone                                                         address registration_date loyalty_status  transaction_id   amount     transaction_date product_category payment_method store_location
# 0              1               Michelle Kidd                   vayala@example.net  +1-619-723-4258                                     USNS Santiago, FPO AE 80872        25-01-2025           Gold               8  2652.57  2025-04-19 14:46:00             Home    Credit Card       New York
# 1              4              Kimberly Price            jessicaknight@example.com  +1-423-222-9779                      1631 Alexis Meadows, Lake Amanda, CA 75179        08-12-2024           Gold             427  1787.09  2025-04-28 04:34:07           Beauty         PayPal        Chicago
# ...

# %%
merged_data.shape
# Out:
# (1000, 13)

# %%
merged_data.head()
# Out:
#    customer_id              name                        email  \
# 0            1     Michelle Kidd           vayala@example.net
# 1            4    Kimberly Price    jessicaknight@example.com
# 2            5  Matthew Phillips        qwilliams@example.com
# 3            7      Louis Miller  patriciaelliott@example.org
# 4            7      Louis Miller  patriciaelliott@example.org
#
#              phone                                            address  \
# 0  +1-619-723-4258                        USNS Santiago, FPO AE 80872
# 1  +1-423-222-9779         1631 Alexis Meadows, Lake Amanda, CA 75179
# 2  +1-220-763-3522  2274 Williams Heights Suite 895, Andersonhaven...
# 3  +1-198-862-7105        02590 Marshall Well, Sheppardland, CT 88067
# 4  +1-198-862-7105        02590 Marshall Well, Sheppardland, CT 88067
#
#   registration_date loyalty_status  transaction_id   amount  \
# 0        25-01-2025           Gold               8  2652.57
# ...

# %%
merged_data.tail()
# Out:
#      customer_id            name                 email            phone  \
# 995          995  Deanna Johnson     ycook@example.org  +1-576-320-4824
# 996          995  Deanna Johnson     ycook@example.org  +1-576-320-4824
# 997          997    Jodi Simpson    eric24@example.org  +1-483-625-2940
# 998          998   Crystal Brown  pshaffer@example.net  +1-390-747-3088
# 999          998   Crystal Brown  pshaffer@example.net  +1-390-747-3088
#
#                                                address registration_date  \
# 995        601 Contreras Forges, Michaelfurt, KY 30733        01-11-2023
# 996        601 Contreras Forges, Michaelfurt, KY 30733        01-11-2023
# 997  2876 Tucker Road Suite 947, North Tommyborough...        18-04-2024
# 998  095 Janice Forest Suite 570, Boltonmouth, DE 7...        30-08-2024
# 999  095 Janice Forest Suite 570, Boltonmouth, DE 7...        30-08-2024
#
#     loyalty_status  transaction_id  amount     transaction_date  \
# ...

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        1000 non-null   int64
#  1   name               1000 non-null   object
#  2   email              1000 non-null   object
#  3   phone              1000 non-null   object
#  4   address            1000 non-null   object
#  5   registration_date  1000 non-null   object
#  6   loyalty_status     1000 non-null   object
#  7   transaction_id     1000 non-null   int64
#  8   amount             950 non-null    float64
#  9   transaction_date   1000 non-null   object
#  10  product_category   1000 non-null   object
#  11  payment_method     1000 non-null   object
#  12  store_location     1000 non-null   object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 101.7+ KB

# %%
merged_data.describe()
# Out:
#        customer_id  transaction_id       amount
# count  1000.000000     1000.000000   950.000000
# mean    489.319000      500.500000  2532.550126
# std     290.525083      288.819436  1428.195244
# min       1.000000        1.000000    11.880000
# 25%     234.000000      250.750000  1274.687500
# 50%     481.500000      500.500000  2577.925000
# 75%     751.000000      750.250000  3749.182500
# max     998.000000     1000.000000  4998.170000

# %%
merged_data.columns
# Out:
# Index(['customer_id', 'name', 'email', 'phone', 'address', 'registration_date',
#        'loyalty_status', 'transaction_id', 'amount', 'transaction_date',
#        'product_category', 'payment_method', 'store_location'],
#       dtype='object')

# %%
merged_data.isnull().sum()
# Out:
# customer_id           0
# name                  0
# email                 0
# phone                 0
# address               0
# registration_date     0
# loyalty_status        0
# transaction_id        0
# amount               50
# transaction_date      0
# product_category      0
# payment_method        0
# store_location        0
# dtype: int64

# %%
merged_data['customer_id'].nunique()
# Out:
# 647

# %%
merged_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Drop duplicate customer records
#merged_data=merged_data.drop_duplicates(subset='customer_id')

# %%
print(merged_data.to_string())
# Out:
#      customer_id                        name                                email            phone                                                         address registration_date loyalty_status  transaction_id   amount     transaction_date product_category payment_method store_location
# 0              1               Michelle Kidd                   vayala@example.net  +1-619-723-4258                                     USNS Santiago, FPO AE 80872        25-01-2025           Gold               8  2652.57  2025-04-19 14:46:00             Home    Credit Card       New York
# 1              4              Kimberly Price            jessicaknight@example.com  +1-423-222-9779                      1631 Alexis Meadows, Lake Amanda, CA 75179        08-12-2024           Gold             427  1787.09  2025-04-28 04:34:07           Beauty         PayPal        Chicago
# ...

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        1000 non-null   int64
#  1   name               1000 non-null   object
#  2   email              1000 non-null   object
#  3   phone              1000 non-null   object
#  4   address            1000 non-null   object
#  5   registration_date  1000 non-null   object
#  6   loyalty_status     1000 non-null   object
#  7   transaction_id     1000 non-null   int64
#  8   amount             950 non-null    float64
#  9   transaction_date   1000 non-null   object
#  10  product_category   1000 non-null   object
#  11  payment_method     1000 non-null   object
#  12  store_location     1000 non-null   object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 101.7+ KB

# %%
merged_data = merged_data.dropna(subset=['amount'])

# %%
mean_amount = merged_data['amount'].mean()

# %%
# 5. Filter: amount > 1000 OR amount > mean
high_value = merged_data[(merged_data['amount'] > 1000) | (merged_data['amount'] > mean_amount)]

# %%
high_value.to_csv("high_value_customers.csv", index=False)

# %%
print(high_value)
# Out:
#      customer_id              name                        email  \
# 0              1     Michelle Kidd           vayala@example.net
# 1              4    Kimberly Price    jessicaknight@example.com
# 2              5  Matthew Phillips        qwilliams@example.com
# 3              7      Louis Miller  patriciaelliott@example.org
# 6             10      Rachel White     whitemichael@example.org
# ..           ...               ...                          ...
# 990          991     Erica Fleming          erica85@example.net
# 991          991     Erica Fleming          erica85@example.net
# 992          992    Thomas Stevens    vargasmatthew@example.org
# 993          995    Deanna Johnson            ycook@example.org
# 994          995    Deanna Johnson            ycook@example.org
#
#                phone                                            address  \
# 0    +1-619-723-4258                        USNS Santiago, FPO AE 80872
# ...
